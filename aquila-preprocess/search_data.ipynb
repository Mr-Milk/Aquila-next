# %%
import pandas as pd
from crossref.restful import Etiquette, Works

# %%
info = Etiquette("aquila", contact_email="yb97643@um.edu.mo")
work = Works(etiquette=info)

# %%
r = work.query('imaging mass cytometry')

# %%
for item in r:
    print(item['title'])
# Out:
# ['Ruthenium counterstaining for imaging mass cytometry']
# ['Imaging Mass Cytometry Modality Overview\xa0 v1']
# ['Imaging Mass Cytometry Modality Overview\xa0 v2']
# ['Signal Amplification for Imaging Mass Cytometry']
# ['Mass Cytometry, Imaging Mass Cytometry, and Multiplexed Ion Beam Imaging Use in a Clinical Setting']
# ['DNA-Conjugated Gold Nanoparticles as High-Mass Probes in Imaging Mass Cytometry']
# ['Imaging Mass Cytometry']
# ['Methods for Analyzing Imaging Mass Cytometry Data with Tellurium Probes']
# ['Metal-Labeled Aptamers as Novel Nanoprobes for Imaging Mass Cytometry Analysis']
# ['Multidimensional Profiling of Drug-Treated Cells by Imaging Mass Cytometry']
# ['Flow Cytometry II: Mass and Imaging Cytometry']
# ['Imaging mass cytometry']
# ['Cutting FFPE Sections for Imaging Mass Cytometry v1']
# ['Decision letter: Multiplexed imaging of immune cells in staged multiple sclerosis lesions by mass cytometry']
# ['Flow Cytometry II: Mass and Imaging Cytometry']
# ...
